# %% [markdown]
# ## Importing required libraries and modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %% [markdown]
# ## Importing and preprocessing data

# %% [markdown]
# #### Importing the dataset into variable df

# %%
df = pd.read_csv('seattle-weather.csv')

# %% [markdown]
# #### Viewing the dataset and understanding its structure

# %%
df.head(10)
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain
# 5  2012-01-06            2.5       4.4       2.2   2.2     rain
# 6  2012-01-07            0.0       7.2       2.8   2.3     rain
# 7  2012-01-08            0.0      10.0       2.8   2.0      sun
# 8  2012-01-09            4.3       9.4       5.0   3.4     rain
# 9  2012-01-10            1.0       6.1       0.6   3.4     rain

# %%
df.shape
# Out:
# (1461, 6)

# %% [markdown]
# The dataset consist of 1461 rows and 6 columns. The first 10 of these values are shown

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB

# %% [markdown]
# The dataset do not contain any null value and consist of 4 fields with 'float64' datatype and 2 fields with 'object' datatype

# %% [markdown]
# #### Preprocessing the dataset

# %%
df.isnull().sum()
# Out:
# date             0
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %% [markdown]
# This confirms that there are no null values in this dataset

# %%
df['weather']=df['weather'].map({'drizzle':0,'rain':1,'sun':2,'snow':3,'fog':4})

# %% [markdown]
# Changing the values of weather column from text to integers

# %% [markdown]
# Weather column contains object data so it has to be converted into numerical data through mapping.

# %% [markdown]
# ## Analysis of data

# %% [markdown]
# #### Statistical Analysis

# %%
df.describe()
# Out:
#        precipitation     temp_max     temp_min         wind      weather
# count    1461.000000  1461.000000  1461.000000  1461.000000  1461.000000
# mean        3.029432    16.439083     8.234771     3.241136     1.644764
# std         6.680194     7.349758     5.023004     1.437825     0.867461
# min         0.000000    -1.600000    -7.100000     0.400000     0.000000
# 25%         0.000000    10.600000     4.400000     2.200000     1.000000
# 50%         0.000000    15.600000     8.300000     3.000000     2.000000
# 75%         2.800000    22.200000    12.200000     4.000000     2.000000
# max        55.900000    35.600000    18.300000     9.500000     4.000000

# %% [markdown]
# Average, minimum and maximum values of precipitation, temp_max, temp_min and wind helps in statistical analysis of the data

# %% [markdown]
# #### Graphical Analysis

# %%
sns.set(rc={'figure.figsize':(20,5)})

# %% [markdown]
# The following plots represent the trend of maximum temprature, precipitation and wind against minimum temprature

# %%
sns.set_style('white')
sns.lineplot(data = df, x = 'temp_min', y = 'temp_max')
plt.title('min temp vs max temp')
plt.xlabel('min temp')
plt.ylabel('max temp')
# Out:
# Text(0, 0.5, 'max temp')

# %%
sns.set_style('white')
sns.lineplot(data = df, x = 'temp_min', y = 'precipitation')
plt.title('min temp vs precipitation')
plt.xlabel('min temp')
plt.ylabel('precipitation')
# Out:
# Text(0, 0.5, 'precipitation')

# %%
sns.set_style('white')
sns.lineplot(data = df, x = 'temp_min', y = 'wind')
plt.title('min temp vs wind')
plt.xlabel('min temp')
plt.ylabel('wind')
# Out:
# Text(0, 0.5, 'wind')

# %% [markdown]
# ## Model Building and Testing

# %% [markdown]
# #### Linear Regression models

# %% [markdown]
# Linear Regression models are used to predict maximum temprature, precipitation and wind based on minimum temprature

# %%
weath_model = LinearRegression()

# %% [markdown]
# The original dataset has to be split into training and testing datasets.

# %%
X_data = df.drop(['date','weather'], axis=1)
Y_data = df.drop(['date','temp_min'], axis=1)

# %%
X_train_weath, X_test_weath, Y_train_weath, Y_test_weath = train_test_split(X_data, Y_data, test_size=0.2, random_state=42)

# %%
model_data_X = X_train_weath[['temp_min']]
model_data_Y = Y_train_weath[['temp_max']]
test_data_X = X_test_weath[['temp_min']]
test_data_Y = Y_test_weath[['temp_max']]

# %% [markdown]
# Training the model and using it to predict values

# %%
weath_model.fit(model_data_X, model_data_Y)
# Out:
# LinearRegression()

# %%
pred_data_Y = weath_model.predict(test_data_X)

# %% [markdown]
# Analysing the effectiveness of the model using plots and performance metrics

# %%
plt.scatter(test_data_X,test_data_Y,color='gray')
plt.plot(test_data_X,pred_data_Y,color='red',linewidth=2)
plt.show()

# %%
print('Mean abolute error is:', mean_absolute_error(test_data_Y,pred_data_Y))
print('Mean squared error is:', mean_squared_error(test_data_Y,pred_data_Y))
print('Root mean squared error is:', np.sqrt(mean_squared_error(test_data_Y,pred_data_Y)))
# Out:
# Mean abolute error is: 2.9665232809078974
# Mean squared error is: 12.804155987686089
# Root mean squared error is: 3.57828953379769

# %%
model_data_X = X_train_weath[['temp_min']]
model_data_Y = Y_train_weath[['precipitation']]
test_data_X = X_test_weath[['temp_min']]
test_data_Y = Y_test_weath[['precipitation']]

# %%
weath_model.fit(model_data_X, model_data_Y)
# Out:
# LinearRegression()

# %%
pred_data_Y = weath_model.predict(test_data_X)

# %%
plt.scatter(test_data_X,test_data_Y,color='gray')
plt.plot(test_data_X,pred_data_Y,color='red',linewidth=2)
plt.show()

# %%
print('Mean abolute error is:', mean_absolute_error(test_data_Y,pred_data_Y))
print('Mean squared error is:', mean_squared_error(test_data_Y,pred_data_Y))
print('Root mean squared error is:', np.sqrt(mean_squared_error(test_data_Y,pred_data_Y)))
# Out:
# Mean abolute error is: 3.9591841947913062
# Mean squared error is: 38.47062027268122
# Root mean squared error is: 6.202468885265062

# %%
model_data_X = X_train_weath[['temp_min']]
model_data_Y = Y_train_weath[['wind']]
test_data_X = X_test_weath[['temp_min']]
test_data_Y = Y_test_weath[['wind']]

# %%
weath_model.fit(model_data_X, model_data_Y)
# Out:
# LinearRegression()

# %%
pred_data_Y = weath_model.predict(test_data_X)

# %%
plt.scatter(test_data_X,test_data_Y,color='gray')
plt.plot(test_data_X,pred_data_Y,color='red',linewidth=2)
plt.show()

# %%
print('Mean abolute error is:', mean_absolute_error(test_data_Y,pred_data_Y))
print('Mean squared error is:', mean_squared_error(test_data_Y,pred_data_Y))
print('Root mean squared error is:', np.sqrt(mean_squared_error(test_data_Y,pred_data_Y)))
# Out:
# Mean abolute error is: 1.1439258968429291
# Mean squared error is: 2.1660460717056975
# Root mean squared error is: 1.471749323664087

# %% [markdown]
# Creating training and testing datasets

# %%
X_train = X_train_weath
Y_train = Y_train_weath[['weather']]
X_test = X_test_weath
Y_test = Y_test_weath[['weather']]

# %%
weath_model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = weath_model.predict(X_test)

# %%
plt.scatter(test_data_X,test_data_Y,color='gray')
plt.plot(test_data_X,pred_data_Y,color='red',linewidth=2)
plt.show()

# %%
print('Mean abolute error is:', mean_absolute_error(test_data_Y,pred_data_Y))
print('Mean squared error is:', mean_squared_error(test_data_Y,pred_data_Y))
print('Root mean squared error is:', np.sqrt(mean_squared_error(test_data_Y,pred_data_Y)))
# Out:
# Mean abolute error is: 1.1439258968429291
# Mean squared error is: 2.1660460717056975
# Root mean squared error is: 1.471749323664087
